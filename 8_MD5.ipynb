# %% [markdown]
# ### Write a program to implement MD5 one way hash function.

# %%
import hashlib

def generate_md5_hash(input_string):
    md5_hash = hashlib.md5()
    md5_hash.update(input_string.encode('utf-8'))
    return md5_hash.hexdigest()

if __name__ == "__main__":
    text = "Rayhanul Islam Mukul"
    hashed_value = generate_md5_hash(text)
    print(f"Plaintext: {text}")
    print("MD5 Hash :", hashed_value)
# Out:
# Plaintext: Rayhanul Islam Mukul
# MD5 Hash : cc6dde76c1c39b2b19937c905346aff8
