# %% [markdown]
# ### Write a program to implement Diffie-Hellman Key Exchange.

# %%
import random

def diffie_hellman(prime, primitive_root):
    # xa = random.randint(1, prime - 1)
    # xb = random.randint(1, prime - 1)
    xa = 97
    xb = 233
    ya = pow(primitive_root, xa, prime)
    yb = pow(primitive_root, xb, prime)
    print(f"A's private key (XA): {xa:3}, Public key (YA): {ya:3}")
    print(f"B's private key (XB): {xb:3}, Public key (YB): {yb:3}")

    ka = pow(yb, xa, prime)
    kb = pow(ya, xb, prime)

    print(f"Shared key at A's end: {ka}")
    print(f"Shared key at B's end: {kb}")

prime = 353
primitive_root = 3
diffie_hellman(prime, primitive_root)
# Out:
# A's private key (XA):  97, Public key (YA):  40
# B's private key (XB): 233, Public key (YB): 248
# Shared key at A's end: 160
# Shared key at B's end: 160
